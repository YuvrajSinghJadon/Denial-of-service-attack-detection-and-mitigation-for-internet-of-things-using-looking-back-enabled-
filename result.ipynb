# %% [markdown]
# ## Experimental results

# %% [markdown]
# 1.Based on the given accuracy and kappa values, the following findings can be derived from the experiment:
#
# 2.The decision tree (DT) and random forest (RF) models perform equally well in terms of accuracy and kappa across all look-back steps. This suggests that these models are robust to changes in the amount of historical data used for training.
#
# 3.The K-Nearest Neighbors (KNN) and Multi-Layer Perceptron (MLP) models have lower accuracy and kappa values compared to the DT and RF models. This suggests that these models may not be well suited for cyberattack prediction or may need further optimization.
#
# 4.The performance of the MLP model decreases as the look-back step increases. This suggests that the model may not be able to learn effectively from a large amount of historical data.
#
# 5.The performance of the KNN model remains constant across all lookback steps. This suggests that beyond a certain point, the model can no longer benefit from additional historical data.
#
# 6.The RF model outperforms the other models in terms of kappa values, suggesting that it's better at capturing the correspondence between predicted and actual labels.
#
# These results suggest that the DT and RF models are well suited for cyberattack prediction and that the amount of historical data used for training can be varied without significantly affecting the model's performance. However, for the KNN and MLP models, further optimization may be required to improve their performance.

# %%
import pandas as pd
import seaborn as sns

# create a dictionary to store the data
data = {
    'Model': ['DT', 'RF', 'KNN', 'MLP'],
    'Basic Approach': [0.9999904593808138, 0.9999904593808138, 0.9999373045024907, 0.9998528018754131],
    'Step 1': [0.9999890964203548, 0.9999890964203548, 0.9999373044170401, 0.9998364463053221],
    'Step 2': [0.9999890963906327, 0.9999890963906327, 0.999937304246138, 0.9998105497872434],
    'Step 3': [0.9999904593027931, 0.999991822259537, 0.9999373039897833, 0.9998200897098128],
    'Step 4': [0.9999904592507786, 0.9999918222149531, 0.9999373036479736, 0.9997573923769414],
}

# create a pandas DataFrame for accuracy table
acc_df = pd.DataFrame(data)
acc_df.set_index('Model', inplace=True)

# create a dictionary to store the kappa score data
data_kappa = {
    'Model': ['DT', 'RF', 'KNN', 'MLP'],
    'Basic Approach': [0.9665, 0.9662, 0.7850, 0.1562],
    'Step 1': [0.9615, 0.9612, 0.7850, 0.1549],
    'Step 2': [0.9615, 0.9612, 0.7850, 0.1472],
    'Step 3': [0.9665, 0.9711, 0.7850, 0.1538],
    'Step 4': [0.9665, 0.9711, 0.7850, 0.1273],
}

# create a pandas DataFrame for kappa score table
kappa_df = pd.DataFrame(data_kappa)
kappa_df.set_index('Model', inplace=True)

# format the tables
acc_df = acc_df.round(5)
kappa_df = kappa_df.round(4)

acc_df.columns = pd.MultiIndex.from_product([['Accuracy'], acc_df.columns])
kappa_df.columns = pd.MultiIndex.from_product([['Kappa Score'], kappa_df.columns])

# create a color gradient for the tables
acc_df_styled = acc_df.style.background_gradient(cmap='Greens', axis=None)
kappa_df_styled = kappa_df.style.background_gradient(cmap='Purples', axis=None)

# display the tables
print("Accuracy Table:\n")
display(acc_df_styled)
print("\nKappa Score Table:\n")
display(kappa_df_styled)
# Out:
# Accuracy Table:
# <style type="text/css">
# #T_7ed3b_row0_col0, #T_7ed3b_row0_col1, #T_7ed3b_row0_col2, #T_7ed3b_row0_col3, #T_7ed3b_row0_col4, #T_7ed3b_row1_col0, #T_7ed3b_row1_col1, #T_7ed3b_row1_col2, #T_7ed3b_row1_col3, #T_7ed3b_row1_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7ed3b_row2_col0, #T_7ed3b_row2_col1, #T_7ed3b_row2_col2, #T_7ed3b_row2_col3, #T_7ed3b_row2_col4 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_7ed3b_row3_col0 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_7ed3b_row3_col1 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_7ed3b_row3_col2 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_7ed3b_row3_col3 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_7ed3b_row3_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7ed3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ed3b_level0_col0" class="col_heading level0 col0" colspan="5">Accuracy</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_7ed3b_level1_col0" class="col_heading level1 col0" >Basic Approach</th>
#       <th id="T_7ed3b_level1_col1" class="col_heading level1 col1" >Step 1</th>
#       <th id="T_7ed3b_level1_col2" class="col_heading level1 col2" >Step 2</th>
#       <th id="T_7ed3b_level1_col3" class="col_heading level1 col3" >Step 3</th>
#       <th id="T_7ed3b_level1_col4" class="col_heading level1 col4" >Step 4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed3b_level0_row0" class="row_heading level0 row0" >DT</th>
#       <td id="T_7ed3b_row0_col0" class="data row0 col0" >0.999990</td>
#       <td id="T_7ed3b_row0_col1" class="data row0 col1" >0.999990</td>
#       <td id="T_7ed3b_row0_col2" class="data row0 col2" >0.999990</td>
#       <td id="T_7ed3b_row0_col3" class="data row0 col3" >0.999990</td>
#       <td id="T_7ed3b_row0_col4" class="data row0 col4" >0.999990</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row1" class="row_heading level0 row1" >RF</th>
#       <td id="T_7ed3b_row1_col0" class="data row1 col0" >0.999990</td>
#       <td id="T_7ed3b_row1_col1" class="data row1 col1" >0.999990</td>
#       <td id="T_7ed3b_row1_col2" class="data row1 col2" >0.999990</td>
#       <td id="T_7ed3b_row1_col3" class="data row1 col3" >0.999990</td>
#       <td id="T_7ed3b_row1_col4" class="data row1 col4" >0.999990</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row2" class="row_heading level0 row2" >KNN</th>
#       <td id="T_7ed3b_row2_col0" class="data row2 col0" >0.999940</td>
#       <td id="T_7ed3b_row2_col1" class="data row2 col1" >0.999940</td>
#       <td id="T_7ed3b_row2_col2" class="data row2 col2" >0.999940</td>
#       <td id="T_7ed3b_row2_col3" class="data row2 col3" >0.999940</td>
#       <td id="T_7ed3b_row2_col4" class="data row2 col4" >0.999940</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row3" class="row_heading level0 row3" >MLP</th>
#       <td id="T_7ed3b_row3_col0" class="data row3 col0" >0.999850</td>
#       <td id="T_7ed3b_row3_col1" class="data row3 col1" >0.999840</td>
#       <td id="T_7ed3b_row3_col2" class="data row3 col2" >0.999810</td>
#       <td id="T_7ed3b_row3_col3" class="data row3 col3" >0.999820</td>
#       <td id="T_7ed3b_row3_col4" class="data row3 col4" >0.999760</td>
#     </tr>
#   </tbody>
# </table>
# Kappa Score Table:
# <style type="text/css">
# #T_7ed1e_row0_col0, #T_7ed1e_row0_col3, #T_7ed1e_row0_col4, #T_7ed1e_row1_col0 {
#   background-color: #40017e;
#   color: #f1f1f1;
# }
# #T_7ed1e_row0_col1, #T_7ed1e_row0_col2 {
#   background-color: #40027e;
#   color: #f1f1f1;
# }
# #T_7ed1e_row1_col1, #T_7ed1e_row1_col2 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_7ed1e_row1_col3, #T_7ed1e_row1_col4 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_7ed1e_row2_col0, #T_7ed1e_row2_col1, #T_7ed1e_row2_col2, #T_7ed1e_row2_col3, #T_7ed1e_row2_col4 {
#   background-color: #65479e;
#   color: #f1f1f1;
# }
# #T_7ed1e_row3_col0, #T_7ed1e_row3_col1, #T_7ed1e_row3_col3 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_7ed1e_row3_col2 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_7ed1e_row3_col4 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_7ed1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ed1e_level0_col0" class="col_heading level0 col0" colspan="5">Kappa Score</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_7ed1e_level1_col0" class="col_heading level1 col0" >Basic Approach</th>
#       <th id="T_7ed1e_level1_col1" class="col_heading level1 col1" >Step 1</th>
#       <th id="T_7ed1e_level1_col2" class="col_heading level1 col2" >Step 2</th>
#       <th id="T_7ed1e_level1_col3" class="col_heading level1 col3" >Step 3</th>
#       <th id="T_7ed1e_level1_col4" class="col_heading level1 col4" >Step 4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed1e_level0_row0" class="row_heading level0 row0" >DT</th>
#       <td id="T_7ed1e_row0_col0" class="data row0 col0" >0.966500</td>
#       <td id="T_7ed1e_row0_col1" class="data row0 col1" >0.961500</td>
#       <td id="T_7ed1e_row0_col2" class="data row0 col2" >0.961500</td>
#       <td id="T_7ed1e_row0_col3" class="data row0 col3" >0.966500</td>
#       <td id="T_7ed1e_row0_col4" class="data row0 col4" >0.966500</td>
#     </tr>
#     <tr>
#       <th id="T_7ed1e_level0_row1" class="row_heading level0 row1" >RF</th>
#       <td id="T_7ed1e_row1_col0" class="data row1 col0" >0.966200</td>
#       <td id="T_7ed1e_row1_col1" class="data row1 col1" >0.961200</td>
#       <td id="T_7ed1e_row1_col2" class="data row1 col2" >0.961200</td>
#       <td id="T_7ed1e_row1_col3" class="data row1 col3" >0.971100</td>
#       <td id="T_7ed1e_row1_col4" class="data row1 col4" >0.971100</td>
#     </tr>
#     <tr>
#       <th id="T_7ed1e_level0_row2" class="row_heading level0 row2" >KNN</th>
#       <td id="T_7ed1e_row2_col0" class="data row2 col0" >0.785000</td>
#       <td id="T_7ed1e_row2_col1" class="data row2 col1" >0.785000</td>
#       <td id="T_7ed1e_row2_col2" class="data row2 col2" >0.785000</td>
#       <td id="T_7ed1e_row2_col3" class="data row2 col3" >0.785000</td>
#       <td id="T_7ed1e_row2_col4" class="data row2 col4" >0.785000</td>
#     </tr>
#     <tr>
#       <th id="T_7ed1e_level0_row3" class="row_heading level0 row3" >MLP</th>
#       <td id="T_7ed1e_row3_col0" class="data row3 col0" >0.156200</td>
#       <td id="T_7ed1e_row3_col1" class="data row3 col1" >0.154900</td>
#       <td id="T_7ed1e_row3_col2" class="data row3 col2" >0.147200</td>
#       <td id="T_7ed1e_row3_col3" class="data row3 col3" >0.153800</td>
#       <td id="T_7ed1e_row3_col4" class="data row3 col4" >0.127300</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd

# Load preprocessed training and testing datasets
train_data = pd.read_csv('Training.csv')
test_data = pd.read_csv('Testing.csv')
unwanted_features = ['pkSeqID', 'proto', 'saddr', 'sport', 'daddr', 'dport', 'category','subcategory']
# train_data.drop(columns=unwanted_features, inplace=True)
# test_data.drop(columns=unwanted_features, inplace=True)
print(train_data.head())
# Out:
#    pkSeqID proto            saddr  sport          daddr dport     seq  \
# 0  3142762   udp  192.168.100.150   6551  192.168.100.3    80  251984
# 1  2432264   tcp  192.168.100.150   5532  192.168.100.3    80  256724
# 2  1976315   tcp  192.168.100.147  27165  192.168.100.3    80   62921
# 3  1240757   udp  192.168.100.150  48719  192.168.100.3    80   99168
# 4  3257991   udp  192.168.100.147  22461  192.168.100.3    80  105063
#
#      stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0  1.900363                100  0.000000             4  2.687519
# 1  0.078003                 38  3.856930             3  3.934927
# 2  0.268666                100  2.974100             3  3.341429
# 3  1.823185                 63  0.000000             4  3.222832
# 4  0.822418                100  2.979995             4  3.983222
#
#    N_IN_Conn_P_DstIP  drate     srate       max  attack category subcategory
# 0                100    0.0  0.494549  4.031619       1     DDoS         UDP
# 1                100    0.0  0.256493  4.012924       1     DDoS         TCP
# 2                100    0.0  0.294880  3.609205       1     DDoS         TCP
# 3                 63    0.0  0.461435  4.942302       1      DoS         UDP
# 4                100    0.0  1.002999  4.994452       1     DDoS         UDP

# %%
print(train_data['attack'].value_counts())
# Out:
# 1    2934447
# 0        370
# Name: attack, dtype: int64

# %%
# group the dataset by two features, e.g. 'feature_1' and 'feature_2', and get the count of each group
counts = train_data.groupby(['category','subcategory']).size()

# print the count of each combination
print(counts)
# Out:
# category        subcategory
# DDoS            HTTP                    786
#                 TCP                  782228
#                 UDP                  758301
# DoS             HTTP                   1184
#                 TCP                  492615
#                 UDP                  826349
# Normal          Normal                  370
# Reconnaissance  OS_Fingerprint        14293
#                 Service_Scan          58626
# Theft           Data_Exfiltration         6
#                 Keylogging               59
# dtype: int64
